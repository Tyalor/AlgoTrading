# %% [markdown]
# ## Time Series Data Analysis

# %% [markdown]
# https://github.com/SMDS-Studio/Predict-Trends-Code-File/blob/main/NeuralProphet.ipynb
#
#
# https://www.youtube.com/watch?v=03H2_ekdv2I
#
# https://www.youtube.com/watch?v=iPQ1yEVniL8
#
# https://www.youtube.com/watch?v=2XGSIlgUBDI
#
# https://www.youtube.com/watch?v=X31hyMhB-3s
#
# https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/
#
# https://towardsdatascience.com/fast-time-series-forecasting-with-statsforecast-694d1670a2f3
#
# https://archive.is/lW8tu
#
# https://wandb.ai/madhana/Time_Series/reports/Python-Time-Series-Forecasting-A-Practical-Approach--VmlldzoyODk4NjUz
#
# https://www.youtube.com/watch?v=b7B5Wlu8KBQ

# %%
# import yfinance as yf
# import pandas as pd
# from statsforecast import StatsForecast
# from statsforecast.models import AutoARIMA
# import matplotlib.pyplot as plt

# # Load your data
# stock_symbols = 'QQQ'
# start_date = '2018-01-01'
# end_date = '2024-01-01'
# df = yf.download(stock_symbols, start=start_date, end=end_date)

# # Prepare the data for historical prices (date and 'Close' price)
# df_historical = df.reset_index()[['Date', 'Close']] # Select the 'Close' column for historical prices
# df_historical.columns = ['ds', 'y']  # Rename columns to 'ds' and 'y'
# df_historical.index.name = 'unique_id'  # Set the index name to 'unique_id' (Added this line)
# df_historical.to_csv("qqq-historical-data.csv")  # Save the historical data to a CSV file

# # Plotting the historical data
# plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['Close'], label='Historical Prices')
# plt.title(f'{stock_symbols} Stock Prices from {start_date} to {end_date}')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# # Create a StatsForecast object without providing the DataFrame
# sf = StatsForecast(models=[AutoARIMA(season_length=12)], freq='D')

# # Fit the model and forecast while specifying the df argument
# forecast = sf.forecast(df=df_historical, h=30)  # Forecasting for 30 days ahead
# forecast_start_date = df_historical['ds'].iloc[-1] + pd.Timedelta(days=1)
# forecast_dates = pd.date_range(start=forecast_start_date, periods=30, freq='D')
# forecast_data = {'Date': forecast_dates, 'Forecast': forecast}
# forecast_df = pd.DataFrame(forecast_data)
# forecast_df.to_csv("qqq-forecast-data.csv")  

# # Plotting the forecast
# plt.figure(figsize=(10, 6))
# plt.plot(df_historical['ds'], df_historical['y'], label='Historical')
# plt.plot(forecast_df['Date'], forecast_df['Forecast'], label='Forecast')
# plt.title(stock_symbols + ' Stock Price Forecast')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# %%
# import yfinance as yf
# import pandas as pd
# from statsforecast import StatsForecast
# from statsforecast.models import AutoARIMA
# import matplotlib.pyplot as plt

# # Load your data
# stock_symbols = 'QQQ'
# start_date = '2018-01-01'
# end_date = '2024-01-01'
# df = yf.download(stock_symbols, start=start_date, end=end_date)

# # Prepare the data for historical prices (date and 'Close' price)
# df_historical = df.reset_index()[['Date', 'Close']]  # Select the 'Close' column for historical prices
# df_historical.columns = ['ds', 'y']  # Rename columns to 'ds' and 'y'
# df_historical['unique_id'] = "1"
# df_historical.to_csv("qqq-historical-data.csv")  # Save the historical data to a CSV file

# # Plotting the historical data
# plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['Close'], label='Historical Prices')
# plt.title(f'{stock_symbols} Stock Prices from {start_date} to {end_date}')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# # Create a StatsForecast object and specify the models
# sf = StatsForecast(
#     models=[AutoARIMA(season_length=12)], 
#     freq='D'
# )

# sf.fit(df_historical)
# sf.predict(h=30, level=[95])

# # Fit the model (you don't need to specify df here) and forecast
# # forecast = sf.forecast(
# #     h=30,  # Forecasting for 30 days ahead
# #     df=df_historical,  # Historical data DataFrame
# #     fitted=False,  # Set to True if you want fitted values
# #     level=tuple(),  # Specify levels if needed
# #     target_col="y",  # Specify the target column
# # )

# # # Extract the 'forecast' column from the DataFrame and convert it to a list
# # forecast_values = forecast['forecast'].tolist()

# # # Create a DataFrame with the forecasted values and columns
# # forecast_dates = pd.date_range(start=df_historical['ds'].iloc[-1] + pd.Timedelta(days=1), periods=30, freq='D')
# # forecast_data = {'Date': forecast_dates, 'Forecast': forecast_values}
# # forecast_df = pd.DataFrame(forecast_data)
# # forecast_df.to_csv("qqq-forecast-data.csv")

# # Plotting the forecast
# # plt.figure(figsize=(10, 6))
# # plt.plot(df_historical['ds'], df_historical['y'], label='Historical')
# # plt.plot(forecast_df['Date'], forecast_df['Forecast'], label='Forecast')
# # plt.title(stock_symbols + ' Stock Price Forecast')
# # plt.xlabel('Date')
# # plt.ylabel('Price')
# # plt.legend()
# # plt.show()

# %%
# import yfinance as yf
# import pandas as pd
# from statsforecast import StatsForecast
# from statsforecast.models import AutoARIMA
# import matplotlib.pyplot as plt

# # Load your data
# stock_symbols = 'QQQ'
# start_date = '2023-06-01'
# end_date = '2024-01-01'
# df = yf.download(stock_symbols, start=start_date, end=end_date)

# # Prepare the data for historical prices (date and 'Close' price)
# df_historical = df.reset_index()[['Date', 'Close']]  # Select the 'Close' column for historical prices
# df_historical.columns = ['ds', 'y']  # Rename columns to 'ds' and 'y'
# df_historical['unique_id'] = "1"
# df_historical.to_csv("qqq-historical-data.csv")  # Save the historical data to a CSV file

# # Plotting the historical data
# plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['Close'], label='Historical Prices')
# plt.title(f'{stock_symbols} Stock Prices from {start_date} to {end_date}')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# # Create a StatsForecast object and specify the models
# sf = StatsForecast(
#     models=[AutoARIMA(season_length=12)], 
#     freq='D'
# )

# sf.fit(df_historical)
# forecast_df = sf.predict(h=60, level=[95])
# forecast_df

# # Plotting the forecast
# plt.figure(figsize=(10, 6))
# plt.plot(df_historical['ds'], df_historical['y'], label='Historical')
# plt.plot(forecast_df['ds'], forecast_df['AutoARIMA'], label='Forecast', color='orange')
# plt.fill_between(forecast_df['ds'], forecast_df['AutoARIMA-lo-95'], forecast_df['AutoARIMA-hi-95'], color='lightgray', alpha=0.5)
# plt.title(f'{stock_symbols} Stock Price Forecast')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# %%
# import yfinance as yf
# import pandas as pd
# from statsforecast import StatsForecast
# from statsforecast.models import AutoARIMA, AutoETS, HistoricAverage, Naive, RandomWalkWithDrift, SeasonalNaive
# import matplotlib.pyplot as plt

# # Load your data
# stock_symbols = 'QQQ'
# start_date = '2023-06-01'
# end_date = '2024-01-01'
# df = yf.download(stock_symbols, start=start_date, end=end_date)

# # Prepare the data for historical prices (date and 'Close' price)
# df_historical = df.reset_index()[['Date', 'Close']]  # Select the 'Close' column for historical prices
# df_historical.columns = ['ds', 'y']  # Rename columns to 'ds' and 'y'
# df_historical['unique_id'] = "1"
# df_historical.to_csv("qqq-historical-data.csv")  # Save the historical data to a CSV file

# # Plotting the historical data
# plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['Close'], label='Historical Prices')
# plt.title(f'{stock_symbols} Stock Prices from {start_date} to {end_date}')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# models = [
#     AutoETS(season_length=24),
#     HistoricAverage(), 
#     Naive(), 
#     RandomWalkWithDrift(), 
#     SeasonalNaive(season_length=24)
# ]

# # Create a StatsForecast object and specify the models
# sf = StatsForecast(
#     models=models, 
#     freq='D'
# )

# sf.fit(df_historical)
# forecast_df = sf.forecast(h=60, level=[95])
# forecast_df

# # average_forecast = []
# # for index, row in forecast_df.iterrows():
# #     average_forecast.append((row["AutoETS-lo-95"] + row["AutoETS-hi-95"]) / 2)
# # forecast_df['Average_ETSprediction'] = average_forecast

# # average_forecast

# # Plotting the forecast
# plt.figure(figsize=(10, 6))
# plt.plot(df_historical['ds'], df_historical['y'], label='Historical')
# plt.plot(forecast_df['ds'], forecast_df['SeasonalNaive'], label='Forecast (Average)', color='orange')
# plt.title(f'{stock_symbols} Stock Price Forecast (Average)')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.show()

# %%
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
# from statsmodels.tsa.arima.model import ARIMA

# # Load stock data
# stock_symbol = 'QQQ'
# start_date = '2023-09-01'
# end_date = '2024-01-01'
# df = yf.download(stock_symbol, start=start_date, end=end_date)

# # Prepare data
# df = df[['Close']]
# df.index = pd.to_datetime(df.index)

# # Split data into training and testing sets
# train_size = int(len(df) * 0.8)
# train_data = df.iloc[:train_size]
# test_data = df.iloc[train_size:]

# # Fit ARIMA model
# p, d, q = 1, 1, 1
# model = ARIMA(train_data, order=(p, d, q))
# model_fit = model.fit()

# # Forecast future stock prices
# forecast_periods = 14
# forecast = model_fit.forecast(steps=forecast_periods)

# # Correct the date range issue for forecasting
# last_date = test_data.index[-1]
# forecast_index = pd.date_range(start=last_date, periods=forecast_periods + 1, freq='B')[1:]  # Business days

# # Visualization
# plt.figure(figsize=(12, 6))
# plt.plot(test_data, label='Actual', color='blue')
# plt.plot(forecast_index, forecast, label='Forecast', color='red', linestyle='--')
# plt.legend()
# plt.xlabel('Date')
# plt.ylabel('Stock Price')
# plt.title(f'Stock Price Forecast for {stock_symbol}')
# plt.grid(True)
# plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# Load stock data
stock_symbol = 'QQQ'
start_date = '2023-06-01'
end_date = '2024-01-01'
df = yf.download(stock_symbol, start=start_date, end=end_date)

# Prepare data
df = df[['Close']]
df.index = pd.to_datetime(df.index)

# Check for stationarity
adf_result = adfuller(df['Close'])
print(f'ADF Statistic: {adf_result[0]}')
print(f'p-value: {adf_result[1]}')
# If p-value > 0.05, the series is not stationary and needs differencing

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

# Find the optimal ARIMA parameters
auto_model = auto_arima(train_data, seasonal=False, stepwise=True, suppress_warnings=True, error_action="ignore", max_order=None, trace=True)

# Fit ARIMA model with the optimal parameters found by auto_arima
model = ARIMA(train_data, order=auto_model.order)
model_fit = model.fit()

# Forecast future stock prices
forecast_periods = 30
forecast, conf_int = model_fit.get_forecast(steps=forecast_periods).summary_frame(alpha=0.05).iloc[:, :2].T.values

# Generate the forecast index
last_date = test_data.index[-1]
forecast_index = pd.date_range(start=last_date, periods=forecast_periods + 1, freq='B')[1:]

# Visualization
plt.figure(figsize=(14, 7))
plt.plot(test_data, label='Actual', color='blue')
plt.plot(forecast_index, forecast[0], label='Forecast', color='red', linestyle='--')
plt.fill_between(forecast_index, conf_int[0], conf_int[1], color='pink', alpha=0.3) # Confidence intervals
plt.legend()
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title(f'Stock Price Forecast for {stock_symbol}')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from pmdarima import auto_arima
#       5 from statsmodels.tsa.arima.model import ARIMA
#       6 from statsmodels.tsa.stattools import adfuller
#
# ModuleNotFoundError: No module named 'pmdarima'
